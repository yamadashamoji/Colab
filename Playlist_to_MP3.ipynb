# %% [markdown]
# <a href="https://colab.research.google.com/github/yamadashamoji/Colab/blob/main/Playlist_to_MP3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title YouTubeのプレイリストURLを入力して、音声をMP3にしてダウンロードする
from google.colab import files
from datetime import datetime

playlist_url = "https://www.youtube.com/playlist?list=PLAoaARHrQjH6YmM8kLkVOj0Mh76zElF61" #@param {type:"string"}

# 現在の日時を取得し、変数nowに代入
now = datetime.now()

# 現在時刻をyyyymmddhhiiss形式で表示
formatted_now = now.strftime('%Y%m%d%H%M%S')

# 出力ファイル名
output_file_name = "playlist_output_"+formatted_now+".mp3";

#プレイリストのmp3を取得
# !pip install yt-dlp
# !yt-dlp -x --audio-format mp3 --yes-playlist -- {playlist_url}

#ダウンロードしたMP3をすべて結合する
# !cat *.mp3 > $output_file_name

# ファイルをダウンロード
files.download(output_file_name)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.5 MB/s eta 0:00:00
# ...
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLAoaARHrQjH6YmM8kLkVOj0Mh76zElF61
# [youtube:tab] PLAoaARHrQjH6YmM8kLkVOj0Mh76zElF61: Downloading webpage
# WARNING: [youtube:tab] YouTube said: INFO - 1 unavailable video is hidden
# [youtube:tab] PLAoaARHrQjH6YmM8kLkVOj0Mh76zElF61: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: initial d OP+ED
# [youtube:tab] PLAoaARHrQjH6YmM8kLkVOj0Mh76zElF61 page 1: Downloading API JSON
# ...

# %% [markdown]
# MP3が結合できない。
# いったんここまで
